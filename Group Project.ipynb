# %%
#Import
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
# Files to load
overall_homeless_data_to_load = "Resources/MD_County_Homeless.csv"
homeless_by_county__data_to_load = "Resources/MD_Homeless_PerCounty.csv"

# %%
# Read School and Student Data Files and store into Pandas DataFrames
overall_homeless_data = pd.read_csv(overall_homeless_data_to_load) 
homeless_by_county_data = pd.read_csv(homeless_by_county__data_to_load)

# %%
# Combine overall homeless and homeless by county data into a single dataset.  
homeless_data_complete = pd.merge(overall_homeless_data, homeless_by_county_data, how="left", on=["County_ID", "County_ID"])

# %%
homeless_data_complete.head()
# Out:
#   County_ID          County_name Civilian_labor_force Employed Unemployed  \
# 0    MD-500      Allegany County               32,253   30,618      1,635
# 1    MD-501       Baltimore city              287,760  273,351     14,409
# 2    MD-502       Harford County              143,572  138,927      4,645
# 3    MD-503  Anne Arundel County              321,069  311,556      9,513
# 4    MD-504        Howard County              191,529  186,427      5,102
#
#    Unemployment_rate Median_Household_Income  \
# 0                5.1                  48,170
# 1                5.0                  49,780
# 2                3.2                  91,492
# 3                3.0                 100,916
# 4                2.7                 121,329
#
#    Med_HH_Income_Percent_of_State_Total Overall Homeless 2019  \
# 0                                  55.6                   145
# 1                                  57.5                 2,294
# 2                                 105.6                   228
# 3                                 116.5                   302
# 4                                 140.0                   201
#
#   Overall Homeless 2018  ... Overall Homeless - Female  \
# 0                    79  ...                        98
# 1                 2,508  ...                       631
# 2                   190  ...                       100
# 3                   366  ...                       112
# 4                   168  ...                        93
#
#   Overall Homeless - Male Overall Homeless - Non-Hispanic  \
# 0                      47                             145
# 1                   1,660                           2,234
# 2                     127                             204
# 3                     189                             296
# 4                     107                             192
#
#    Overall Homeless - Hispanic/Latino  Overall Homeless - White  \
# 0                                   0                       119
# 1                                  60                       602
# 2                                  24                       116
# 3                                   6                       164
# 4                                   9                        45
#
#   Overall Homeless - Black or African American  Overall Homeless - Asian  \
# 0                                           14                         0
# 1                                        1,609                        15
# 2                                           83                         1
# 3                                          118                         1
# 4                                          132                         2
#
#   Overall Homeless - American Indian or Alaska Native  \
# 0                                                  0
# 1                                                 25
# 2                                                  2
# 3                                                  1
# 4                                                  5
#
#   Overall Homeless - Native Hawaiian or Other Pacific Islander  \
# 0                                                  0
# 1                                                  8
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Overall Homeless - Multiple Races
# 0                                 12
# 1                                 35
# 2                                 26
# 3                                 18
# 4                                 16
#
# [5 rows x 26 columns]
